# %% [markdown]
# LANGGRAPH STUDIO INTERFACE
#
# ![image.png](attachment:94424f59-fdf3-42d5-b38a-4960be0a2bfd.png)
#
# GRAPH STATES
#
# ![image.png](attachment:0336bebd-4e30-41f7-8dd7-c3c3115bbc6b.png)
